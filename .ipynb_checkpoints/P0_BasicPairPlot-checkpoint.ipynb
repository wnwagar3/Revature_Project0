# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
student_data_df = pd.read_csv("combined_student_data.csv")
student_data_df.head()
# Out:
#      Student_ID  math_score  reading_score  writing_score  \
# 0  CC2F443C5C99          58             68             69
# 1  22E7A1158638          62             70             68
# 2  AE79A2647B1A          83             85             84
# 3  6E39B11464EC          84             93             87
# 4  2CA5D66C2B57          73             83             92
#
#    parental_level_of_education  lunch_plan  test_preparation_course Gender  \
# 0                            1           1                        0      F
# 1                            3           2                        0      F
# 2                            4           2                        0      F
# 3                            3           2                        0      F
# 4                            5           2                        0      F
#
#   Year_Group
# 0    Group A
# 1    Group A
# 2    Group A
# 3    Group A
# 4    Group A

# %%
student_data_df.shape
# Out:
# (1000, 9)

# %%
student_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Student_ID                   1000 non-null   object
#  1   math_score                   1000 non-null   int64
#  2   reading_score                1000 non-null   int64
#  3   writing_score                1000 non-null   int64
#  4   parental_level_of_education  1000 non-null   int64
#  5   lunch_plan                   1000 non-null   int64
#  6   test_preparation_course      1000 non-null   int64
#  7   Gender                       1000 non-null   object
#  8   Year_Group                   1000 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 70.4+ KB

# %%
student_data_df['Gender'] = student_data_df['Gender'].map({"F": 0, "M":1})

# %%
student_data_df.head()
# Out:
#      Student_ID  math_score  reading_score  writing_score  \
# 0  CC2F443C5C99          58             68             69
# 1  22E7A1158638          62             70             68
# 2  AE79A2647B1A          83             85             84
# 3  6E39B11464EC          84             93             87
# 4  2CA5D66C2B57          73             83             92
#
#    parental_level_of_education  lunch_plan  test_preparation_course  Gender  \
# 0                            1           1                        0       0
# 1                            3           2                        0       0
# 2                            4           2                        0       0
# 3                            3           2                        0       0
# 4                            5           2                        0       0
#
#   Year_Group
# 0    Group A
# 1    Group A
# 2    Group A
# 3    Group A
# 4    Group A

# %%
unique_year_groups = student_data_df['Year_Group'].unique()
print(unique_year_groups)
# Out:
# ['Group A' 'Group B' 'Group C' 'Group D' 'Group E']

# %%
student_data_df['Year_Group'] = student_data_df['Year_Group'].map({"Group A" : 0, "Group B" : 1, "Group C": 2, 
                                                                   "Group D" : 3, 'Group E' : 4})

# %%
student_data_df.sample(10)
# Out:
#        Student_ID  math_score  reading_score  writing_score  \
# 628  12F1FE1AF216          80             94             97
# 360  9A1460731552          52             60             62
# 655  76FF6E4F240C          75             75             75
# 937  8FA43DD771B2          80             77             73
# 978  4C6303134A1E          90             97             94
# 821  F09D1FCF3966          64             65             61
# 393  B6216E2EADCE          40             50             52
# 44   2A5EA8897879          82             86             89
# 471  932F0D2360F8          72             66             60
# 79   4AE08C879D70          47             47             43
#
#      parental_level_of_education  lunch_plan  test_preparation_course  Gender  \
# 628                            6           1                        1       0
# 360                            4           2                        0       0
# ...

# %%
sns.pairplot(student_data_df)
plt.show()
